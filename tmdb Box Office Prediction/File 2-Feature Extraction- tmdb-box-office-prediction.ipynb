# %% [markdown]
# Help is taken from notebook : https://www.kaggle.com/artgor/eda-feature-engineering-and-model-interpretation

# %%
import numpy as np
import eli5
import lightgbm as lgb
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
import ast
from sklearn.model_selection import train_test_split
from collections import Counter
import wordcloud
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud

# %%
data=r"C:\Users\bhardwaj\Downloads\tmdb-box-office-prediction\train.csv"

# %%
df=pd.read_csv(data)

# %%
df.set_index('id',inplace=True)

# %%
df.isnull().sum()
# Out:
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# dtype: int64

# %%
df.dtypes
# Out:
# belongs_to_collection     object
# budget                     int64
# genres                    object
# homepage                  object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# Keywords                  object
# cast                      object
# crew                      object
# revenue                    int64
# dtype: object

# %%
for i, e in enumerate(df['genres'][:10]):
    print(i, e)
# Out:
# 0 [{'id': 35, 'name': 'Comedy'}]
# 1 [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 10749, 'name': 'Romance'}]
# 2 [{'id': 18, 'name': 'Drama'}]
# 3 [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}]
# 4 [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}]
# 5 [{'id': 16, 'name': 'Animation'}, {'id': 12, 'name': 'Adventure'}, {'id': 10751, 'name': 'Family'}]
# 6 [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}]
# 7 [{'id': 99, 'name': 'Documentary'}]
# 8 [{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}, {'id': 10402, 'name': 'Music'}, {'id': 10751, 'name': 'Family'}, {'id': 12, 'name': 'Adventure'}]
# 9 [{'id': 35, 'name': 'Comedy'}, {'id': 10402, 'name': 'Music'}]

# %%
dict_columns = ['belongs_to_collection', 'genres', 'production_companies',
                'production_countries', 'spoken_languages', 'Keywords', 'cast', 'crew']

# %%
def text_to_dict(df):
    for column in dict_columns:
        df[column] = df[column].apply(lambda x: {} if pd.isna(x) else ast.literal_eval(x) )
    return df

# %%
df = text_to_dict(df)
df['genres']
# Out:
# id
# 1                          [{'id': 35, 'name': 'Comedy'}]
# 2       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 3                           [{'id': 18, 'name': 'Drama'}]
# 4       [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 5       [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 6       [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 7       [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 8                     [{'id': 99, 'name': 'Documentary'}]
# 9       [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 10      [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 11                          [{'id': 18, 'name': 'Drama'}]
# 12                         [{'id': 35, 'name': 'Comedy'}]
# 13                          [{'id': 18, 'name': 'Drama'}]
# 14      [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 15      [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 16      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 17      [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 18      [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 19      [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 20      [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 21      [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 22      [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 23      [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 24      [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 25      [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 26      [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 27      [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 28      [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 29                      [{'id': 16, 'name': 'Animation'}]
# 30      [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#                               ...
# 2971    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 2972    [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...
# 2973    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 2974    [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2975    [{'id': 28, 'name': 'Action'}, {'id': 14, 'nam...
# 2976    [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 2977    [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 2978    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2979    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2980    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2981    [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2982                        [{'id': 18, 'name': 'Drama'}]
# 2983                        [{'id': 18, 'name': 'Drama'}]
# 2984    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2985    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 2986    [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 2987    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 2988    [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2989                        [{'id': 18, 'name': 'Drama'}]
# 2990    [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 2991    [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2992    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 2993    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2994    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2995                        [{'id': 18, 'name': 'Drama'}]
# 2996    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2997    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2998    [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2999    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 3000    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# Name: genres, Length: 3000, dtype: object

# %% [markdown]
# ###### Creating dummy has_collection for the movies that actually belongs to collection.

# %%
df['has_collection'] = df['belongs_to_collection'].apply(lambda x: len(x) if x != {} else 0)

# %%
df['has_collection'].value_counts()
# Out:
# 0    2396
# 1     604
# Name: has_collection, dtype: int64

# %% [markdown]
# ###### There are many movies with more than 1 genre. Therefore let's account for 15 most common genres in movies and how having this genre affect revenue.

# %%
print('Number of genres in films')
df['genres'].apply(lambda x: len(x) if x != {} else 0).value_counts()
# Out:
# Number of genres in films
# 2    972
# 3    900
# 1    593
# 4    393
# 5    111
# 6     21
# 0      7
# 7      3
# Name: genres, dtype: int64

# %%
list_of_genres = list(df['genres'].apply(lambda x: [i['name'] for i in x] if x != {} else []).values)

# %%
text = ' '.join([i for j in list_of_genres for i in j]) ## here we created a text with the every genre in it to create word cloud.

# %%
wordcloud=WordCloud(collocations=False).generate(text)

# %%
plt.imshow(wordcloud)

# %% [markdown]
# Comedy, Drama and Thriller are some of the most common genres.

# %%
df['num_genres'] = df['genres'].apply(lambda x: len(x) if x != {} else 0)
df['all_genres']=df['genres'].apply(lambda x: " ".join(sorted([i['name'] for i in x])) if x != {} else '') ## Added space in the quotes to add space between genres
top_genres = [m[0] for m in Counter([i for j in list_of_genres for i in j]).most_common(15)] ## with m[0] I only took the name of genres in top 15 list and not the column of counts.
for g in top_genres:
    df['genre_' + g] = df['all_genres'].apply(lambda x: 1 if g in x else 0)
## So here created dummy for top 15 genres.

# %% [markdown]
# ###### Similarly creating dummies for top 20 most common languages movie is released in and top 20 most common production companies and countries.

# %%
df['original_language'].value_counts()
for i, e in enumerate(df['spoken_languages'][:10]):
    print(i, e)
    print('Number of languages film is released in ')
df['spoken_languages'].apply(lambda x: len(x) if x != {} else 0).value_counts()
## most of the movies are released in only 1 language.
list_of_languages = list(df['spoken_languages'].apply(lambda x: [i['iso_639_1'] for i in x] if x != {} else []).values)
df['num_lan'] = df['spoken_languages'].apply(lambda x: len(x) if x != {} else 0)
df['all_lan']=df['spoken_languages'].apply(lambda x: " ".join(sorted([i['iso_639_1'] for i in x])) if x != {} else '') ## Added space in the quotes to add space between genres
spok_lang = [m[0] for m in Counter([i for j in list_of_languages for i in j]).most_common(20)] ## with m[0] I only took the name of genres in top 15 list and not the column of counts.
for g in spok_lang:
    df['spoken_language_' + g] = df['all_lan'].apply(lambda x: 1 if g in x else 0)
# Out:
# 0 [{'iso_639_1': 'en', 'name': 'English'}]
# Number of languages film is released in
# 1 [{'iso_639_1': 'en', 'name': 'English'}]
# Number of languages film is released in
# 2 [{'iso_639_1': 'en', 'name': 'English'}]
# Number of languages film is released in
# 3 [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# Number of languages film is released in
# 4 [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# Number of languages film is released in
# 5 [{'iso_639_1': 'en', 'name': 'English'}]
# Number of languages film is released in
# 6 [{'iso_639_1': 'en', 'name': 'English'}]
# Number of languages film is released in
# 7 [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso_639_1': 'en', 'name': 'English'}]
# Number of languages film is released in
# 8 [{'iso_639_1': 'en', 'name': 'English'}]
# Number of languages film is released in
# 9 [{'iso_639_1': 'en', 'name': 'English'}]
# Number of languages film is released in

# %%
print('No. of production companies ')
print(df['production_companies'].apply(lambda x: len(x) if x != {} else 0).value_counts())
list_of_companies = list(df['production_companies'].apply(lambda x: [i['name'] for i in x] if x != {} else []).values)
df['num_pcomp'] = df['production_companies'].apply(lambda x: len(x) if x != {} else 0)
df['all_pcomp']=df['production_companies'].apply(lambda x: " ".join(sorted([i['name'] for i in x])) if x != {} else '') ## Added space in the quotes to add space between genres
top_prod_comp=[m[0] for m in Counter([i for j in list_of_companies for i in j]).most_common(20)] ## with m[0] I only took the name of genres in top 15 list and not the column of counts.
for g in top_prod_comp:
    df['prod_comp_' + g] = df['all_pcomp'].apply(lambda x: 1 if g in x else 0)
# Out:
# No. of production companies
# 1     775
# 2     734
# 3     582
# 4     312
# 5     166
# 0     156
# 6     118
# 7      62
# 8      42
# 9      29
# 11      7
# 10      7
# 12      3
# 16      2
# 15      2
# 14      1
# 13      1
# 17      1
# Name: production_companies, dtype: int64

# %%
print('No. of production countries ')
print(df['production_countries'].apply(lambda x: len(x) if x != {} else 0).value_counts())
list_of_countries = list(df['production_countries'].apply(lambda x: [i['name'] for i in x] if x != {} else []).values)
df['num_pcoun'] = df['production_companies'].apply(lambda x: len(x) if x != {} else 0)
df['all_pcoun']=df['production_companies'].apply(lambda x: " ".join(sorted([i['name'] for i in x])) if x != {} else '') ## Added space in the quotes to add space between genres
top_prod_coun=[m[0] for m in Counter([i for j in list_of_countries for i in j]).most_common(20)] ## with m[0] I only took the name of genres in top 15 list and not the column of counts.
for g in top_prod_coun:
    df['prod_coun_' + g] = df['all_pcoun'].apply(lambda x: 1 if g in x else 0)
# Out:
# No. of production countries
# 1    2222
# 2     525
# 3     116
# 4      57
# 0      55
# 5      21
# 6       3
# 8       1
# Name: production_countries, dtype: int64

# %%
df['status'].value_counts()
# Out:
# Released    2996
# Rumored        4
# Name: status, dtype: int64

# %% [markdown]
# Since almost all the movies are release, it does not seem beneficial to keep this variable.

# %%
print('No. of key words ')
print(df['Keywords'].apply(lambda x: len(x) if x != {} else 0).value_counts())
list_of_keywords = list(df['Keywords'].apply(lambda x: [i['name'] for i in x] if x != {} else []).values)
df['num_keyword'] = df['Keywords'].apply(lambda x: len(x) if x != {} else 0)
df['all_keyword']=df['Keywords'].apply(lambda x: " ".join(sorted([i['name'] for i in x])) if x != {} else '') ## Added space in the quotes to add space between genres
top_keyword=[m[0] for m in Counter([i for j in list_of_keywords for i in j]).most_common(20)]
for g in top_keyword:
    df['keyword_' + g] = df['all_keyword'].apply(lambda x: 1 if g in x else 0)
# Out:
# No. of key words
# 5      293
# 0      276
# 4      248
# 3      228
# 6      227
# 2      207
# 7      192
# 1      187
# 8      161
# 9      134
# 11     132
# 10     125
# 12     100
# 13      85
# 14      59
# 15      59
# 16      58
# 17      45
# 18      29
# 20      24
# 21      23
# 19      22
# 22      17
# 23      15
# 24      12
# 27      12
# 25       6
# 26       5
# 32       2
# 28       2
# 30       2
# 31       2
# 29       2
# 37       2
# 43       1
# 40       1
# 38       1
# 33       1
# 97       1
# 39       1
# 149      1
# Name: Keywords, dtype: int64

# %% [markdown]
# ###### Extracting 20 most common actors from the cast variable and their gender.

# %%
print('No. of actors ')
print(df['cast'].apply(lambda x: len(x) if x != {} else 0).value_counts())
list_of_cast = list(df['cast'].apply(lambda x: [i['name'] for i in x] if x != {} else []).values)
print('Gender of actors ')
print(df['cast'].apply(lambda x: len(x) if x != {} else 0).value_counts())
list_of_gcast = list(df['cast'].apply(lambda x: [i['gender'] for i in x] if x != {} else []).values)
# Out:
# No. of actors
# 15     212
# 16     165
# 10     135
# 13     129
# 12     124
# 11     122
# 9      118
# 17     118
# 18     115
# 14     110
# 8      106
# 19     102
# 7       96
# 20      93
# 22      77
# 6       76
# 23      71
# 21      68
# 5       57
# 24      57
# 4       52
# 25      50
# 27      44
# 29      42
# 26      39
# 31      37
# 30      32
# 28      30
# 32      26
# 0       26
#       ...
# 69       2
# 98       2
# 75       2
# 76       2
# 117      2
# 77       2
# 105      2
# 80       2
# 103      1
# 95       1
# 81       1
# 89       1
# 87       1
# 85       1
# 113      1
# 83       1
# 115      1
# 91       1
# 64       1
# 156      1
# 122      1
# 118      1
# 112      1
# 108      1
# 92       1
# 90       1
# 88       1
# 84       1
# 82       1
# 134      1
# Name: cast, Length: 109, dtype: int64
# Gender of actors
# 15     212
# 16     165
# 10     135
# 13     129
# 12     124
# 11     122
# 9      118
# 17     118
# 18     115
# 14     110
# 8      106
# 19     102
# 7       96
# 20      93
# 22      77
# 6       76
# 23      71
# 21      68
# 5       57
# 24      57
# 4       52
# 25      50
# 27      44
# 29      42
# 26      39
# 31      37
# 30      32
# 28      30
# 32      26
# 0       26
#       ...
# 69       2
# 98       2
# 75       2
# 76       2
# 117      2
# 77       2
# 105      2
# 80       2
# 103      1
# 95       1
# 81       1
# 89       1
# 87       1
# 85       1
# 113      1
# 83       1
# 115      1
# 91       1
# 64       1
# 156      1
# 122      1
# 118      1
# 112      1
# 108      1
# 92       1
# 90       1
# 88       1
# 84       1
# 82       1
# 134      1
# Name: cast, Length: 109, dtype: int64

# %%
df['num_cast'] = df['cast'].apply(lambda x: len(x) if x != {} else 0)
df['all_cast']=df['cast'].apply(lambda x: " ".join(sorted([i['name'] for i in x])) if x != {} else '') ## Added space in the quotes to add space between genres
top_cast=[m[0] for m in Counter([i for j in list_of_cast for i in j]).most_common(20)] ## with m[0] I only took the name of genres in top 15 list and not the column of counts.
for g in top_cast:
    df['cast_' + g] = df['all_cast'].apply(lambda x: 1 if g in x else 0)
    list_of_cast_genders = list(df['cast'].apply(lambda x: [i['gender'] for i in x] if x != {} else []).values)
Counter([i for j in list_of_cast_genders for i in j]).most_common()
len(list_of_cast)
# Out:
# 3000

# %% [markdown]
# ###### Extracting 15  most common crew names and their gender from the crew variable.

# %%
df['crew'].apply(lambda x: len(x) if x != {} else 0).value_counts().head(10)
list_of_crew_names = list(df['crew'].apply(lambda x: [i['name'] for i in x] if x != {} else []).values)
print(Counter([i for j in list_of_crew_names for i in j]).most_common(15))
list_of_crew_jobs = list(df['crew'].apply(lambda x: [i['job'] for i in x] if x != {} else []).values)
print(Counter([i for j in list_of_crew_jobs for i in j]).most_common(15))
list_of_crew_genders = list(df['crew'].apply(lambda x: [i['gender'] for i in x] if x != {} else []).values)
print(Counter([i for j in list_of_crew_genders for i in j]).most_common(15))
list_of_crew_departments = list(df['crew'].apply(lambda x: [i['department'] for i in x] if x != {} else []).values)
print(Counter([i for j in list_of_crew_departments for i in j]).most_common(14))
list_of_crew_names = df['crew'].apply(lambda x: [i['name'] for i in x] if x != {} else []).values
# Out:
# [('Avy Kaufman', 50), ('Robert Rodriguez', 44), ('Deborah Aquila', 40), ('James Newton Howard', 39), ('Mary Vernieu', 38), ('Steven Spielberg', 37), ('Luc Besson', 37), ('Jerry Goldsmith', 37), ('Francine Maisler', 35), ('Tricia Wood', 35), ('James Horner', 33), ('Kerry Barden', 32), ('Bob Weinstein', 30), ('Harvey Weinstein', 30), ('Janet Hirshenson', 30)]
# [('Producer', 6011), ('Executive Producer', 3459), ('Director', 3225), ('Screenplay', 2996), ('Editor', 2824), ('Casting', 2483), ('Director of Photography', 2288), ('Original Music Composer', 1947), ('Art Direction', 1821), ('Production Design', 1650), ('Costume Design', 1573), ('Writer', 1523), ('Set Decoration', 1345), ('Makeup Artist', 1108), ('Sound Re-Recording Mixer', 970)]
# [(0, 41787), (2, 24898), (1, 6412)]
# [('Production', 15887), ('Sound', 9319), ('Art', 8069), ('Crew', 7315), ('Writing', 6567), ('Costume & Make-Up', 6156), ('Camera', 5424), ('Directing', 4954), ('Editing', 4508), ('Visual Effects', 3591), ('Lighting', 1303), ('Actors', 4)]

# %%
df['num_crew'] = df['crew'].apply(lambda x: len(x) if x != {} else 0)
top_crew_names = [m[0] for m in Counter([i for j in list_of_crew_names for i in j]).most_common(15)]
for g in top_crew_names:
    df['crew_name_' + g] = df['crew'].apply(lambda x: 1 if g in str(x) else 0)
df['genders_0_crew'] = df['crew'].apply(lambda x: sum([1 for i in x if i['gender'] == 0]))
df['genders_1_crew'] = df['crew'].apply(lambda x: sum([1 for i in x if i['gender'] == 1]))
df['genders_2_crew'] = df['crew'].apply(lambda x: sum([1 for i in x if i['gender'] == 2]))
top_crew_jobs = [m[0] for m in Counter([i for j in list_of_crew_jobs for i in j]).most_common(15)]
for j in top_crew_jobs:
    df['jobs_' + j] = df['crew'].apply(lambda x: sum([1 for i in x if i['job'] == j]))
top_crew_departments = [m[0] for m in Counter([i for j in list_of_crew_departments for i in j]).most_common(15)]
for j in top_crew_departments:
    df['departments_' + j] = df['crew'].apply(lambda x: sum([1 for i in x if i['department'] == j]))

# %% [markdown]
# ###### Extracting the year in which movie is released and month in which movie is released.

# %%
def fix_date(x):
    """
    Fixes dates which are in 20xx
    """
    year = x.split('/')[2]
    if int(year) <= 19:
        return x[:-2] + '20' + year
    else:
        return x[:-2] + '19' + year

# %%
df['release_date'] = df['release_date'].apply(lambda x: fix_date(x))
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
def process_date(data):
    date_parts = ["year", "weekday", "month", 'weekofyear', 'day', 'quarter']
    for part in date_parts:
        part_col = 'release_date' + "_" + part
        data[part_col] = getattr(data['release_date'].dt, part).astype(int)
        return data

# %%
process_date(df)
# Out:
#                                   belongs_to_collection     budget  \
# id
# 1     [{'id': 313576, 'name': 'Hot Tub Time Machine ...   14000000
# 2     [{'id': 107674, 'name': 'The Princess Diaries ...   40000000
# 3                                                    {}    3300000
# 4                                                    {}    1200000
# 5                                                    {}          0
# 6                                                    {}    8000000
# 7                                                    {}   14000000
# 8                                                    {}          0
# 9     [{'id': 256377, 'name': 'The Muppet Collection...          0
# 10                                                   {}    6000000
# 11    [{'id': 1575, 'name': 'Rocky Collection', 'pos...    1000000
# 12    [{'id': 48190, 'name': 'Revenge of the Nerds C...          0
# 13                                                   {}   15000000
# 14    [{'id': 91698, 'name': 'Chili Palmer Collectio...   53000000
# 15                                                   {}  102000000
# 16                                                   {}     500000
# 17                                                   {}   26000000
# 18                                                   {}          0
# 19                                                   {}    8000000
# 20    [{'id': 9518, 'name': 'The Transporter Collect...   32000000
# 21                                                   {}   80000000
# 22    [{'id': 9735, 'name': 'Friday the 13th Collect...    4000000
# 23    [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 24                                                   {}          0
# 25                                                   {}          0
# 26                                                   {}          0
# 27                                                   {}   10000000
# 28                                                   {}   11000000
# 29                                                   {}    6000000
# 30                                                   {}   45000000
# ...                                                 ...        ...
# 2971                                                 {}   25000000
# 2972                                                 {}   20000000
# 2973                                                 {}          0
# 2974                                                 {}          0
# 2975  [{'id': 149704, 'name': 'Alone in the Dark Col...   20000000
# 2976                                                 {}   45000000
# 2977                                                 {}   16000000
# 2978                                                 {}   53000000
# 2979                                                 {}          0
# 2980                                                 {}   35000000
# 2981                                                 {}     300000
# 2982                                                 {}          0
# 2983                                                 {}     500000
# 2984                                                 {}   35000000
# 2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...   80000000
# 2986                                                 {}   37665000
# 2987                                                 {}   20000000
# 2988                                                 {}          0
# 2989                                                 {}          0
# 2990                                                 {}          0
# 2991                                                 {}          0
# 2992  [{'id': 107469, 'name': 'Save The Last Dance C...   13000000
# 2993                                                 {}    1135654
# 2994                                                 {}   60000000
# 2995                                                 {}          0
# 2996                                                 {}          0
# 2997                                                 {}          0
# 2998                                                 {}   65000000
# 2999                                                 {}   42000000
# 3000                                                 {}   35000000
#
#                                                  genres  \
# id
# 1                        [{'id': 35, 'name': 'Comedy'}]
# 2     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 3                         [{'id': 18, 'name': 'Drama'}]
# 4     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 5     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 6     [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 7     [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 8                   [{'id': 99, 'name': 'Documentary'}]
# 9     [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 10    [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 11                        [{'id': 18, 'name': 'Drama'}]
# 12                       [{'id': 35, 'name': 'Comedy'}]
# 13                        [{'id': 18, 'name': 'Drama'}]
# 14    [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 15    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 16    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 17    [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 18    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 19    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 20    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 21    [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 22    [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 23    [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 24    [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 25    [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 26    [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 27    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 28    [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 29                    [{'id': 16, 'name': 'Animation'}]
# 30    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# ...                                                 ...
# 2971  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 2972  [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...
# 2973  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 2974  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2975  [{'id': 28, 'name': 'Action'}, {'id': 14, 'nam...
# 2976  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 2977  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 2978  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2979  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2980  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2981  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2982                      [{'id': 18, 'name': 'Drama'}]
# 2983                      [{'id': 18, 'name': 'Drama'}]
# 2984  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2985  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 2986  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 2987  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 2988  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2989                      [{'id': 18, 'name': 'Drama'}]
# 2990  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 2991  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2992  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 2993  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2994  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2995                      [{'id': 18, 'name': 'Drama'}]
# 2996  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2997  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2998  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2999  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 3000  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                                homepage    imdb_id  \
# id
# 1                                                   NaN  tt2637294
# 2                                                   NaN  tt0368933
# 3                     http://sonyclassics.com/whiplash/  tt2582802
# 4                            http://kahaanithefilm.com/  tt1821480
# 5                                                   NaN  tt1380152
# 6                                                   NaN  tt0093743
# 7                    http://www.thepossessionmovie.com/  tt0431021
# 8                                                   NaN  tt0391024
# 9                                                   NaN  tt0117110
# 10                                                  NaN  tt0310281
# 11                                                  NaN  tt0075148
# 12                                                  NaN  tt0093857
# 13                        http://www.dreamworks.com/ab/  tt0169547
# 14                                                  NaN  tt0377471
# 15                                                  NaN  tt0181689
# 16                http://skinningmovie.com/synopsis.htm  tt1129437
# 17                                                  NaN  tt0421239
# 18                                                  NaN  tt1700845
# 19                                                  NaN  tt1487118
# 20                                                  NaN  tt0388482
# 21                                                  NaN  tt0120738
# 22                                                  NaN  tt0083972
# 23                  http://www.magnetreleasing.com/vhs/  tt2105044
# 24                          http://insightthemovie.com/  tt1687277
# 25                  http://www.blacksheep-themovie.com/  tt0779982
# 26                                                  NaN  tt0104139
# 27                                                  NaN  tt0120176
# 28                                                  NaN  tt1486834
# 29                                                  NaN  tt0092106
# 30                                                  NaN  tt0264472
# ...                                                 ...        ...
# 2971                                                NaN  tt0103855
# 2972                                                NaN  tt0100201
# 2973                                                NaN  tt0482930
# 2974                                                NaN  tt0089652
# 2975                                                NaN  tt0369226
# 2976              http://www.aliensintheatticmovie.com/  tt0775552
# 2977                                                NaN  tt0186045
# 2978  http://angeleyesmovie.warnerbros.com/index_nof...  tt0225071
# 2979                                                NaN  tt0120879
# 2980                     http://www.theback-upplan.com/  tt1212436
# 2981           https://www.facebook.com/Actionherobiju/  tt5320514
# 2982                                                NaN  tt4158876
# 2983                                                NaN  tt2063781
# 2984                                                NaN  tt0118623
# 2985        http://www.sonypictures.com/homevideo/swat/  tt0257076
# 2986  http://www.sonypictures.com/homevideo/freedoml...  tt0349467
# 2987                                                NaN  tt0338325
# 2988                                                NaN  tt0096246
# 2989                                                NaN  tt0301978
# 2990                                                NaN  tt0206367
# 2991                                                NaN  tt0118663
# 2992                                                NaN  tt0206275
# 2993                                                NaN  tt0015400
# 2994               http://www.theterminal-themovie.com/  tt0362227
# 2995                                                NaN  tt0105327
# 2996                                                NaN  tt0109403
# 2997                                                NaN  tt2364975
# 2998                                                NaN  tt0116908
# 2999                     http://www.alongcamepolly.com/  tt0343135
# 3000                   http://www.abductionthefilm.com/  tt1600195
#
#      original_language                              original_title  \
# id
# 1                   en                      Hot Tub Time Machine 2
# 2                   en    The Princess Diaries 2: Royal Engagement
# 3                   en                                    Whiplash
# 4                   hi                                     Kahaani
# 5                   ko                                        마린보이
# 6                   en      Pinocchio and the Emperor of the Night
# 7                   en                              The Possession
# 8                   en                                Control Room
# 9                   en                      Muppet Treasure Island
# 10                  en                               A Mighty Wind
# 11                  en                                       Rocky
# 12                  en  Revenge of the Nerds II: Nerds in Paradise
# 13                  en                             American Beauty
# 14                  en                                     Be Cool
# 15                  en                             Minority Report
# 16                  sr                                     Šišanje
# 17                  en                                     Red Eye
# 18                  en                         The Invisible Woman
# 19                  en                                 Chalet Girl
# 20                  en                               Transporter 2
# 21                  en                               Lost in Space
# 22                  en                    Friday the 13th Part III
# 23                  en                                       V/H/S
# 24                  en                                     InSight
# 25                  en                                 Black Sheep
# 26                  en                                 Dr. Giggles
# 27                  en                        The Spanish Prisoner
# 28                  en                                     What If
# 29                  en                 The Transformers: The Movie
# 30                  en                              Changing Lanes
# ...                ...                                         ...
# 2971                en                               The Bodyguard
# 2972                en                                 Mr. Destiny
# 2973                cn                                         龍虎門
# 2974                en                          My Science Project
# 2975                en                           Alone in the Dark
# 2976                en                         Aliens in the Attic
# 2977                en                               Drowning Mona
# 2978                en                                  Angel Eyes
# 2979                en                             Velvet Goldmine
# 2980                en                            The Back-Up Plan
# 2981                ml                             ആക്ഷൻ ഹീറോ ബിജു
# 2982                en                                Other People
# 2983                en                                     Smashed
# 2984                en                               Anna Karenina
# 2985                en                                    S.W.A.T.
# 2986                en                                 Freedomland
# 2987                en                                   Paparazzi
# 2988                en                           The Terror Within
# 2989                fa                                          ده
# 2990                en                     The Trumpet Of The Swan
# 2991                en                                    B.A.P.S.
# 2992                en                         Save the Last Dance
# 2993                en                         The Thief of Bagdad
# 2994                en                                The Terminal
# 2995                en                                 School Ties
# 2996                en                                     Chasers
# 2997                sv                                 Vi är bäst!
# 2998                en                     The Long Kiss Goodnight
# 2999                en                            Along Came Polly
# 3000                en                                   Abduction
#
#                                                overview  popularity  \
# id
# 1     When Lou, who has become the "father of the In...    6.575393
# 2     Mia Thermopolis is now a college graduate and ...    8.248895
# 3     Under the direction of a ruthless instructor, ...   64.299990
# 4     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 5     Marine Boy is the story of a former national s...    1.148070
# 6     Pinocchio and his friends, a glow worm and a m...    0.743274
# 7     A young girl buys an antique box at a yard sal...    7.286477
# 8     A chronicle which provides a rare window into ...    1.949044
# 9     After telling the story of Flint's last journe...    6.902423
# 10    In "A Mighty Wind", director Christopher Guest...    4.672036
# 11    When world heavyweight boxing champion, Apollo...   14.774066
# 12    The members of the Lambda Lambda Lambda frater...   10.543750
# 13    Lester Burnham, a depressed suburban father in...   20.726578
# 14    Disenchanted with the movie industry, Chili Pa...   13.314233
# 15    John Anderton is a top 'Precrime' cop in the l...   20.666063
# 16    Novica is a mathematics champion in a Belgrade...    1.018477
# 17    After attending the funeral of her grandmother...    6.336927
# 18    In 1857, at the height of his fame and fortune...    4.183558
# 19    While working a job at an exclusive ski resort...    6.496259
# 20    Professional driver Frank Martin is living in ...   11.359659
# 21    The prospects for continuing life on Earth in ...   12.000579
# 22    An idyllic summer turns into a nightmare of un...    7.992290
# 23    When a group of misfits is hired by an unknown...    7.820787
# 24    Kaitlyn, an ER nurse who is tending to a young...    1.323333
# 25    A genetic engineering experiment gone horribly...    7.434577
# 26    In 1957, Evan Rendell flees after his father i...    1.252367
# 27    An employee of a corporation with a lucrative ...    4.305735
# 28    Wallace, a medical school dropout, has been re...   10.841891
# 29    The Autobots must stop a colossal planet-consu...    6.759181
# 30    A rush-hour fender-bender on New York City's c...    7.818620
# ...                                                 ...         ...
# 2971  A former Secret Service agent grudgingly takes...    9.805017
# 2972  Larry Burrows is unhappy and feels powerless o...    4.414928
# 2973  Dragon Tiger Gate is a 2006 Hong Kong martial ...    4.154861
# 2974  Michael and Ellie break into a military junkya...    3.868014
# 2975  Edward Carnby is a private investigator specia...    5.871243
# 2976  It's summer vacation, but the Pearson family k...   11.618472
# 2977  The recently deceased Mona Dearly (Bette Midle...    4.372616
# 2978  A story about a seemingly unlikely couple who ...    5.396200
# 2979  Almost a decade has elapsed since Bowiesque gl...   16.529300
# 2980  When Zoe tires of looking for Mr. Right, she d...    6.629999
# 2981  Biju is an honest policeman who fights the inj...    0.350207
# 2982  David, a struggling comedy writer fresh off fr...    3.069108
# 2983  Kate and Charlie like to have a good time. The...    4.893812
# 2984  Anna (Marceau) is a wife and mother who has an...    5.660835
# 2985  Hondo Harrelson recruits Jim Street to join an...   13.334952
# 2986  A black police detective must solve a strange ...    5.388535
# 2987  A rising Hollywood actor decides to take perso...   12.553403
# 2988  Experiments in biological warfare have destroy...    1.292125
# 2989  A visual social examination in the form of ten...    0.984515
# 2990  The adventures of a young Trumpeter swan who c...    0.851599
# 2991  Can two clueless Georgia homegirls with big he...    1.560980
# 2992  A white midwestern girl moves to Chicago, wher...    4.794088
# 2993  A recalcitrant thief vies with a duplicitous M...    3.878515
# 2994  Viktor Navorski is a man without a country; hi...   14.092373
# 2995  When David Greene receives a football scholars...    7.438381
# 2996  Military men Rock Reilly and Eddie Devane are ...    9.853270
# 2997  Three girls in 1980s Stockholm decide to form ...    3.727996
# 2998  Samantha Caine, suburban homemaker, is the ide...   14.482345
# 2999  Reuben Feffer is a guy who's spent his entire ...   15.725542
# 3000  A young man sets out to uncover the truth abou...   10.512109
#
#                            poster_path  ... departments_Crew  \
# id                                      ...
# 1     /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg  ...                4
# 2     /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg  ...                0
# 3     /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg  ...                9
# 4     /aTXRaPrWSinhcmCrcfJK17urp3F.jpg  ...                0
# 5     /m22s7zvkVFDU9ir56PiiqIEWFdT.jpg  ...                0
# 6     /6IDqA1D2NBIVhzEEaMMRL28iBrq.jpg  ...                0
# 7     /4QjzFuaZmB4btGnLwAgdp23BzIU.jpg  ...               11
# 8     /83BV8fGy5p9i8RwE9oj76tZ1Ikp.jpg  ...                0
# 9     /5A8gKzOrF9Z7tSUX6xd5dEx4NXf.jpg  ...                0
# 10    /xwD4EsPOGLuKP50Q1gwqAsyhAFB.jpg  ...                0
# 11    /i5xiwdSsrecBvO7mIfAJixeEDSg.jpg  ...                5
# 12    /1KTi0wJQfyi8YnAjuP1xQ0Hr9m4.jpg  ...                0
# 13    /or1MP8BZIAjqWYxPdPX724ydKar.jpg  ...               23
# 14      /ekKCH7Zkb5ZTr1f1AczZY23FH.jpg  ...                0
# 15    /h3lpltSn7Rj1eYTPQO1lYGdw4Bz.jpg  ...               36
# 16    /88l8VBanH0lS5Wvzu2qgkGcsfQi.jpg  ...                5
# 17    /rTDa8Ald7iiES01zJJkcM9ikd0l.jpg  ...                1
# 18    /cIMdqerF4DuVEYnkSQPWLc9qAc2.jpg  ...                2
# 19    /64AQrBEKJVSIRaocOCtkMqExToz.jpg  ...                0
# 20    /bZKkwfQf4mHYlNbmViNjmAN60zY.jpg  ...                0
# 21    /kkBDPkUnYwAkWbYY2bnyf5ANObA.jpg  ...               25
# 22    /5wg2NZyIhcMbIBAahBODXHyJ54S.jpg  ...                0
# 23    /yo49x6Jhr1ecCjy1ByFqwAbtARJ.jpg  ...                0
# 24    /7oJksA5Bi7UdrVZhudIg6GaHpRz.jpg  ...                0
# 25    /8YoL8WSHv7UKTq7iziI7SrRmdql.jpg  ...                0
# 26    /5JDLNXWiSCVRLur0oziJk6q5VVk.jpg  ...                3
# 27    /cwkWlWfFrvH6WW6ovX5gfGHo7ks.jpg  ...                0
# 28    /g5vPBCJbBX36oikg68brcl7PU5a.jpg  ...                0
# 29    /yGuQ2lz41EgjbnPeimXR9klTOoq.jpg  ...                0
# 30    /dCTVH1kl3aIkUmWpMT5STLAwsPs.jpg  ...                0
# ...                                ...  ...              ...
# 2971  /cbUiIu4357JQ4FBCtRJovHNv1gi.jpg  ...                9
# 2972  /6dgR1qZK3cTx90P8T6pmVCWYyko.jpg  ...                0
# 2973  /7KjTa35LiROUVWkCEEkHBALUEfB.jpg  ...                0
# 2974  /fLknudxoi1qSNnvtOlNSYRYL8Hq.jpg  ...                1
# 2975  /3HsprIjUEwYfnlEf7jumGm037Bk.jpg  ...                0
# 2976  /oxds3BQ99FdOxiR24Z5I7N5ELwv.jpg  ...                4
# 2977  /tAkoosobX8wEwIJnPICEhrCI7H5.jpg  ...                0
# 2978  /jxchJRFZO6zYgdVaAOgNWLNM4yW.jpg  ...                0
# 2979  /jhRPjcw24WK0RTPYT9IFEykwnKp.jpg  ...                0
# 2980  /1Ig6ZQpLZfLsdvMLHD0inc2w0HB.jpg  ...                1
# 2981  /2Gs9TXEwFnjyvwSFKmsm437hvq3.jpg  ...                0
# 2982  /8zYkVlVF63TwNhb9mjCqTjwkETE.jpg  ...                0
# 2983  /clBwWIRhFqYiHIUbveYgoPnB3fV.jpg  ...                0
# 2984  /6TkouR90wy44GGQtYihYNOJffJp.jpg  ...                0
# 2985  /AgwobKKS20WRaQCHj5ut2R4KyHa.jpg  ...               22
# 2986  /uoYZmNzUjTEvW0vktaVfMRJZA8s.jpg  ...                0
# 2987  /jiMiZqO56mVfKK7amclP9aUrfuz.jpg  ...                3
# 2988  /tyQJBO1yB2rlhgy7QGW9W459jZM.jpg  ...                2
# 2989  /lnleX6mbaa8aeBnIgttD49FH2PU.jpg  ...                0
# 2990  /aGCgEUFmibemCD2cfQZVQKyPPG3.jpg  ...                0
# 2991  /kdAJ4Q5uE1I8KhiJnoc3HvESynE.jpg  ...                2
# 2992  /jnutEFGGdjJrLDxzJykI4ZviGe8.jpg  ...                1
# 2993  /a6IzXkwZRDimfn8HATzP6Pi6Ois.jpg  ...                4
# 2994  /f4Dup6awDfDqAHKgWqNJ2HFw1qN.jpg  ...                3
# 2995  /poV3j71mcmQkmjezc2H35xJsAhD.jpg  ...                0
# 2996  /j8Q7pQ27hvH54wpxJzIuQgQCdro.jpg  ...                0
# 2997  /sS01LSy6KDrCZAhtkO18UdnWFT1.jpg  ...                0
# 2998  /4MENR8x6mYqnZvp2hGjSaPJz64J.jpg  ...                1
# 2999  /nIY4kvJTTnxoBR0wycrXng5MOYs.jpg  ...               10
# 3000  /cUT6NQP5LAJpmUoStGtXmvNt4zA.jpg  ...                4
#
#      departments_Writing departments_Costume & Make-Up  departments_Camera  \
# id
# 1                      2                            13                   8
# 2                      1                             0                   1
# 3                      1                             5                   4
# 4                      1                             0                   0
# 5                      1                             0                   0
# 6                      4                             0                   0
# 7                      4                            12                  11
# 8                      0                             0                   0
# 9                      2                             0                   1
# 10                     2                             1                   1
# 11                     1                             1                   3
# 12                     1                             0                   0
# 13                     3                            11                   7
# 14                     2                             0                   1
# 15                     4                            14                  15
# 16                     4                             3                   3
# 17                     1                            14                   1
# 18                     2                             3                   1
# 19                     1                             0                   0
# 20                     4                             0                   2
# 21                     3                             9                   7
# 22                     5                             0                   1
# 23                     6                             0                   0
# 24                     2                             0                   1
# 25                     1                             1                   1
# 26                     2                             0                   1
# 27                     1                             1                   1
# 28                     3                             0                   1
# 29                     1                             0                   1
# 30                     2                             0                   1
# ...                  ...                           ...                 ...
# 2971                   1                             7                   6
# 2972                   2                             0                   1
# 2973                   1                             0                   1
# 2974                   1                             2                   1
# 2975                   3                             0                   1
# 2976                   2                             0                   0
# 2977                   1                             0                   0
# 2978                   1                             1                   1
# 2979                   3                             1                   1
# 2980                   1                             0                   1
# 2981                   2                             0                   1
# 2982                   1                             1                   1
# 2983                   2                             0                   1
# 2984                   1                             0                   0
# 2985                   6                             9                   7
# 2986                   1                             1                   1
# 2987                   1                             3                   5
# 2988                   1                             0                   1
# 2989                   0                             0                   0
# 2990                   1                             0                   0
# 2991                   1                             6                   1
# 2992                   2                             1                   1
# 2993                   4                             3                   3
# 2994                   3                            15                   6
# 2995                   2                             2                   1
# 2996                   5                             0                   1
# 2997                   2                             0                   1
# 2998                   1                             0                   1
# 2999                   1                            14                   9
# 3000                   1                             7                   3
#
#      departments_Directing departments_Editing departments_Visual Effects  \
# id
# 1                        4                   2                          4
# 2                        1                   1                          0
# 3                        3                   6                          3
# 4                        1                   0                          0
# 5                        1                   0                          0
# 6                        1                   0                          4
# 7                        4                   9                          2
# 8                        1                   0                          0
# 9                        1                   1                          0
# 10                       1                   1                          0
# 11                       4                   4                          0
# 12                       1                   0                          0
# 13                       5                   8                          8
# 14                       1                   2                          0
# 15                       4                   6                         13
# 16                       1                   2                          0
# 17                       2                   3                          0
# 18                       1                   1                          3
# 19                       1                   0                          0
# 20                       2                   2                          0
# 21                       5                   4                         11
# 22                       1                   1                          1
# 23                      10                   0                          0
# 24                       1                   1                          0
# 25                       1                   1                          0
# 26                       1                   1                          0
# 27                       2                   1                          0
# 28                       1                   1                          0
# 29                       1                   1                          0
# 30                       1                   1                          0
# ...                    ...                 ...                        ...
# 2971                     2                   4                          0
# 2972                     1                   0                          0
# 2973                     1                   0                          0
# 2974                     1                   1                          0
# 2975                     1                   1                          0
# 2976                     1                   0                          4
# 2977                     1                   0                          0
# 2978                     1                   1                          0
# 2979                     2                   2                          0
# 2980                     1                   1                          1
# 2981                     1                   0                          0
# 2982                     1                   1                          0
# 2983                     2                   1                          0
# 2984                     1                   0                          0
# 2985                     3                   4                          4
# 2986                     1                   1                          0
# 2987                     2                   2                          0
# 2988                     1                   1                          1
# 2989                     1                   1                          0
# 2990                     2                   1                          0
# 2991                     1                   1                          0
# 2992                     2                   2                          0
# 2993                     3                   1                          1
# 2994                     3                   5                          4
# 2995                     1                   2                          0
# 2996                     1                   1                          0
# 2997                     2                   1                          0
# 2998                     1                   1                          0
# 2999                     4                   9                          0
# 3000                     2                   2                          5
#
#      departments_Lighting departments_Actors release_date_year
# id
# 1                       4                  0              2015
# 2                       0                  0              2004
# 3                       1                  0              2014
# 4                       0                  0              2012
# 5                       0                  0              2009
# 6                       0                  0              1987
# 7                       4                  0              2012
# 8                       0                  0              2004
# 9                       0                  0              1996
# 10                      0                  0              2003
# 11                      1                  0              1976
# 12                      0                  0              1987
# 13                      3                  0              1999
# 14                      0                  0              2005
# 15                      7                  0              2002
# 16                      0                  0              2010
# 17                      0                  0              2005
# 18                      0                  0              2013
# 19                      0                  0              2011
# 20                      0                  0              2005
# 21                      4                  0              1998
# 22                      0                  0              1982
# 23                      0                  0              2012
# 24                      0                  0              2011
# 25                      0                  0              2006
# 26                      0                  0              1992
# 27                      0                  0              1997
# 28                      0                  0              2013
# 29                      0                  0              1986
# 30                      0                  0              2002
# ...                   ...                ...               ...
# 2971                    1                  0              1992
# 2972                    0                  0              1990
# 2973                    0                  0              2006
# 2974                    0                  0              1985
# 2975                    0                  0              2005
# 2976                    1                  0              2009
# 2977                    0                  0              2000
# 2978                    0                  0              2001
# 2979                    0                  0              1998
# 2980                    0                  0              2010
# 2981                    0                  0              2016
# 2982                    0                  0              2016
# 2983                    0                  0              2012
# 2984                    0                  0              1997
# 2985                    6                  0              2003
# 2986                    0                  0              2006
# 2987                    0                  0              2004
# 2988                    0                  0              1989
# 2989                    0                  0              2002
# 2990                    0                  0              2001
# 2991                    0                  0              1997
# 2992                    0                  0              2001
# 2993                    1                  0              1924
# 2994                    3                  0              2004
# 2995                    0                  0              1992
# 2996                    0                  0              1994
# 2997                    0                  0              2013
# 2998                    0                  0              1996
# 2999                    3                  0              2004
# 3000                    0                  0              2011
#
# [3000 rows x 197 columns]

# %%
df['release_month']=getattr(df['release_date'].dt,'month')

# %%
df['release_year']=getattr(df['release_date'].dt,'year')

# %%
df['release_year'].value_counts()
# Out:
# 2013    141
# 2015    128
# 2010    126
# 2016    125
# 2012    125
# 2011    124
# 2014    123
# 2006    114
# 2009    106
# 2007    105
# 2008    101
# 2005     99
# 2002     84
# 2004     83
# 2001     77
# 2003     74
# 1998     66
# 1999     65
# 2000     65
# 1997     63
# 1995     62
# 1993     56
# 1988     56
# 1996     55
# 1994     51
# 1989     47
# 1990     46
# 1992     45
# 1987     45
# 1986     44
#        ...
# 1959      5
# 1956      4
# 1936      4
# 1951      4
# 1965      4
# 1961      4
# 1945      4
# 1939      4
# 1958      3
# 1957      3
# 1942      3
# 1928      3
# 1932      3
# 1940      2
# 1944      2
# 1950      2
# 1949      2
# 1943      2
# 1933      2
# 1931      2
# 1927      2
# 1925      2
# 1947      2
# 1926      1
# 1930      1
# 1952      1
# 1938      1
# 1935      1
# 1921      1
# 1924      1
# Name: release_year, Length: 90, dtype: int64

# %%
df.describe()
# Out:
#              budget   popularity      runtime       revenue  has_collection  \
# count  3.000000e+03  3000.000000  2998.000000  3.000000e+03     3000.000000
# mean   2.253133e+07     8.463274   107.856571  6.672585e+07        0.201333
# std    3.702609e+07    12.104000    22.086434  1.375323e+08        0.401063
# min    0.000000e+00     0.000001     0.000000  1.000000e+00        0.000000
# 25%    0.000000e+00     4.018053    94.000000  2.379808e+06        0.000000
# 50%    8.000000e+06     7.374861   104.000000  1.680707e+07        0.000000
# 75%    2.900000e+07    10.890983   118.000000  6.891920e+07        0.000000
# max    3.800000e+08   294.337037   338.000000  1.519558e+09        1.000000
#
#         num_genres  genre_Drama  genre_Comedy  genre_Thriller  genre_Action  \
# count  3000.000000  3000.000000   3000.000000     3000.000000   3000.000000
# mean      2.503667     0.510333      0.342667        0.263000      0.247000
# std       1.117021     0.499977      0.474680        0.440336      0.431339
# min       0.000000     0.000000      0.000000        0.000000      0.000000
# 25%       2.000000     0.000000      0.000000        0.000000      0.000000
# 50%       2.000000     1.000000      0.000000        0.000000      0.000000
# 75%       3.000000     1.000000      1.000000        1.000000      0.000000
# max       7.000000     1.000000      1.000000        1.000000      1.000000
#
#        ...  departments_Costume & Make-Up  departments_Camera  \
# count  ...                     3000.00000         3000.000000
# mean   ...                        2.05200            1.808000
# std    ...                        3.51142            2.560597
# min    ...                        0.00000            0.000000
# 25%    ...                        0.00000            0.000000
# 50%    ...                        1.00000            1.000000
# 75%    ...                        2.00000            2.000000
# max    ...                       33.00000           23.000000
#
#        departments_Directing  departments_Editing  departments_Visual Effects  \
# count            3000.000000          3000.000000                 3000.000000
# mean                1.651333             1.502667                    1.197000
# std                 1.353653             1.726940                    3.733475
# min                 0.000000             0.000000                    0.000000
# 25%                 1.000000             0.000000                    0.000000
# 50%                 1.000000             1.000000                    0.000000
# 75%                 2.000000             2.000000                    0.000000
# max                30.000000            14.000000                   52.000000
#
#        departments_Lighting  departments_Actors  release_date_year  \
# count           3000.000000         3000.000000        3000.000000
# mean               0.434333            0.001333        1999.713000
# std                1.235393            0.044709          15.423313
# min                0.000000            0.000000        1921.000000
# 25%                0.000000            0.000000        1993.000000
# 50%                0.000000            0.000000        2004.000000
# 75%                0.000000            0.000000        2011.000000
# max               12.000000            2.000000        2017.000000
#
#        release_month  release_year
# count    3000.000000   3000.000000
# mean        6.775333   1999.713000
# std         3.409115     15.423313
# min         1.000000   1921.000000
# 25%         4.000000   1993.000000
# 50%         7.000000   2004.000000
# 75%        10.000000   2011.000000
# max        12.000000   2017.000000
#
# [8 rows x 175 columns]

# %%
df.to_csv (r'C:\Users\bhardwaj\Downloads\tmdb-box-office-prediction\dataframe1.csv', header=True) #Don't forget to add '.csv' at the end of the path
